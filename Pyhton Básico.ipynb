# %%
1.5*5

# %%
"Eu amo minha mulher" + " 5.000.000 de vezes"

# %%
type(False)

# %%
type(true)

# %%
True or False

# %%
True and False

# %%
not False

# %%
not True

# %%
1==2

# %%
1 == 1

# %%
a = 5
b = 2
c = a/b

c

# %%
b = 4
c = c+1
c

# %%
b = "olá"
type(b)

# %%
a = 3
b = 2

a
b

# %%
a = "Oi"
print(a)
b = "Deu errado"
print(b)

# %%
print("""
      quebra 
      de 
      linha
      """)

# %%
aluno = 'Antonio'
print("O nome do aluno é: "+ aluno)

# %%
print(1,2,3)
print('o próximo número é:',4)

print('O nome do aluno é: ' + aluno)

# %%
f"Atenção {aluno} sua note está disponível"

# %%
matricula = 123
nota = (10+8+9)/3

f"O aluno {aluno} com a matricula: {matricula} teve a média de: {nota}"
