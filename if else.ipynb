# %%
if True:
    print("True")
else:
    print("False")

# %%
if 1>2:
    print("Igual")
else:
    print("Não igual")

# %%
comida = 'feijao'

if comida == 'arroz':
    print(f"Eu amo{comida}")
else:
    print(f"Eu não gosto de {comida}")

# %%
if bool:
    code_1
elif:
    code_2
else:
    code_3

# %%
comida = 'feijão'

if comida == 'feijão':
    print(f"Eu amo {comida}")
elif comida == 'arroz':
    print(f"Eu gosto de {comida}")
elif comida == 'carne':
    print(f"Eu gosto de {comida}")
else:
    print(f"Eu não gosto de {comida}")

# %%
A = 20
B = 25
C = 15

wallet = 20
if A <= 20:
    print("João vai ao próximo")
elif A and B >= 20:
    print("João não vai comer nem em A, nem em B")
else:
    wallet = wallet - C
    print(f"João vai comer em C e tem {wallet} reais na carteira")

# %%
wallet = 20
A = 25
if A <= wallet:
    print("João vai almoçar")
else: 
    print("João não vai almoçar ali")

# %%
B = 25

if A <= wallet:
    print("João vai almoçar no A")
elif B <= wallet:
    print("João vai almoçar no B")
else:
    print("João não vai almoçar em nenhum")

# %%
c = 15

if A <= wallet:
    print("João vai almoçar no A")
elif B <= wallet:
    print("João vai almoçar no B")
elif C <= wallet:
    print("João vai almoçar no C")
    troco = wallet - c
    if troco >=5:
        print("João vai comer um doce")
    else:
        print("João não vai comer doce")
else:
    print("João não vai almoçar em nenhum")
